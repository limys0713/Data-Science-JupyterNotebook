# %%
import pandas as pd

# %% [markdown]
# READ THE FILE FIRST

# %%
def read_imdb_data_with_pandas(file_path):
    # Load the CSV file into a Pandas DataFrame
    data = pd.read_csv(file_path)
    
    # Remove any extra spaces around the '|'
    # This will ensure that all actor names are consistent and don't have extra spaces
    data['Actors'] = data['Actors'].apply(lambda x: '|'.join([actor.strip() for actor in x.split('|')]))
    
    return data

data = read_imdb_data_with_pandas("IMDB-Movie-Data.csv")
#data.head(10)
data["Actors"].head(10)
# Out:
# 0    Christian Bale|Heath Ledger|Aaron Eckhart|Mich...
# 1    Leonardo DiCaprio|Joseph Gordon-Levitt|Ellen P...
# 2    Aamir Khan|Sakshi Tanwar|Fatima Sana Shaikh|Sa...
# 3    Matthew McConaughey|Anne Hathaway|Jessica Chas...
# 4    Ryunosuke Kamiki|Mone Kamishiraishi|Ryo Narita...
# 5    Francois Cluzet|Omar Sy|Anne Le Ny|Audrey Fleurot
# 6    Christian Bale|Hugh Jackman|Scarlett Johansson...
# 7    Leonardo DiCaprio|Matt Damon|Jack Nicholson|Ma...
# 8    Christian Bale|Tom Hardy|Anne Hathaway|Gary Ol...
# 9    Miles Teller|J.K. Simmons|Melissa Benoist|Paul...
# Name: Actors, dtype: object

# %% [markdown]
# QUESTION 1

# %%
# Question 1
def top_3_movies_with_highest_ratings_in_2016(data):
    # Filter out the movies that is released in 2016
    # Pandas boolean indexing 
    # Use for filtering the DataFrame and data 
    movies_in_2016 = data[data["Year"] == 2016 ]
    # Find the top 3 unique ratings
    top_3_ratings = movies_in_2016["Rating"].drop_duplicates().nlargest(3)
    # Select only the "Title" "Rating" columns from the filtered result
    # Double Bracketes are for multiple columns
    # Filter the movies that have a rating in the top 3 ratings
    answer = movies_in_2016[movies_in_2016["Rating"].isin(top_3_ratings)][["Title", "Rating"]]
    # Sort the answer by rating in descending order
    answer = answer.sort_values(by="Rating", ascending=False)

    return answer

question_1 = top_3_movies_with_highest_ratings_in_2016(data)
question_1
# Out:
#              Title  Rating
# 2           Dangal     8.8
# 4    Kimi no na wa     8.6
# 15  Koe no katachi     8.4

# %% [markdown]
# QUESTION 2

# %%
# Question 2
def actor_with_highest_average_revenue_per_movie(data):
    # Split the 'Actors' column into individual actors and explode into rows
    actors_data = data.assign(Actors=data["Actors"].str.split('|')).explode("Actors")
    # Group by actor and calc. the average revenue per movie
    actor_revenue = actors_data.groupby("Actors")["Revenue (Millions)"].mean()
    # Find the highest average revenue
    max_average_revenue = actor_revenue.max()
    # Find all actors who have this max. average revenue
    answer = actor_revenue[actor_revenue == max_average_revenue]
    
    return answer

question_2 = actor_with_highest_average_revenue_per_movie(data)
question_2
# Out:
# Actors
# Daisy Ridley    936.63
# John Boyega     936.63
# Name: Revenue (Millions), dtype: float64

# %% [markdown]
# QUESTION 3

# %%
def average_rating_of_EmmaWatson_movies(data):
    # Filter rows where the "Actors" column contains "Emma Watson"
    emma_watson_movies = data[data["Actors"].str.contains("Emma Watson")]
    # Calc. the mean of the rating in "Rating" column for those movies
    answer = emma_watson_movies["Rating"].mean()

    return answer

question_3 = average_rating_of_EmmaWatson_movies(data)
print(f"The average rating of Emma Watson's movies is {question_3:.3f}")
# Out:
# The average rating of Emma Watson's movies is 7.175

# %% [markdown]
# QUESTION 4

# %%
def top_3_directors_collaborate_with_most_actors(data):
    # Split "Actors" and explode the list of actors into individual rows
    directors_data = data.assign(Actors=data["Actors"].str.split('|')).explode("Actors")
    # Group by 'Director' and count the number of collaborated actors 
    # nunique(): Count the number of unique actors 
    director_actor_count = directors_data.groupby("Director")["Actors"].nunique()
    # Get the top 3 unique numbers of collaborated actors
    top_3_numbers_collaborated_actors = director_actor_count.drop_duplicates().nlargest(3)
    answer = director_actor_count[director_actor_count.isin(top_3_numbers_collaborated_actors)].reset_index(name="Number of Collaborated Actors")
    # Sort the answer by rating in descending order
    answer = answer.sort_values(by="Number of Collaborated Actors", ascending=False)

    return answer

question_4 = top_3_directors_collaborate_with_most_actors(data)
question_4
# Out:
#              Director  Number of Collaborated Actors
# 3        Ridley Scott                             28
# 1  M. Night Shyamalan                             24
# 0         Danny Boyle                             20
# 2  Paul W.S. Anderson                             20

# %% [markdown]
# QUESTION 5

# %%
def top_2_actors_playing_most_genres_movies(data):
    # Split 'Actors' and 'Genre' into lists
    actors_genres = data.assign(Actors=data["Actors"].str.split('|'), Genre=data["Genre"].str.split('|'))
    # Explode the 'Actors' column first, then the 'Genre' column
    actors_genres = actors_genres.explode("Actors").explode("Genre")    
    # Group by actor and count the number of unique genres they have played in
    actor_genre_count = actors_genres.groupby("Actors")["Genre"].nunique()
    # Get the top 2 actors with the most unique genres
    top_2_numbers_genres = actor_genre_count.drop_duplicates().nlargest(2)
    answer = actor_genre_count[actor_genre_count.isin(top_2_numbers_genres)].reset_index(name="Number of Genre Movies")
    # Sort the answer by rating in descending order
    answer = answer.sort_values(by="Number of Genre Movies", ascending=False)

    return answer

question_5 = top_2_actors_playing_most_genres_movies(data)
question_5
# Out:
#                Actors  Number of Genre Movies
# 1           Brad Pitt                      14
# 0           Amy Adams                      13
# 2  Chloe Grace Moretz                      13
# 3        Hugh Jackman                      13
# 4         Johnny Depp                      13
# 5  Scarlett Johansson                      13

# %% [markdown]
# QUESTION 6

# %%
def actors_with_largest_movie_gap_year(data):
    # Split the 'Actors' column and explode into individual rows
    actors_data = data.assign(Actors=data["Actors"].str.split('|')).explode("Actors")
    # Group by actor and find the min. and max. year for each actor
    # agg(): Aggregation functions to the grouped data
    actor_year_gap = actors_data.groupby("Actors").agg(min_year=("Year", "min"), max_year=("Year", "max"))
    # Calc. the gap between the minimum and maximum year
    actor_year_gap["gap"] = actor_year_gap["max_year"] - actor_year_gap["min_year"]
    # Find all of the actors with the largest gap
    max_gap = actor_year_gap["gap"].max()
    answer = actor_year_gap[actor_year_gap["gap"] == max_gap]
    # Count the number of rows
    answer_number_actors = len(answer)

    return answer, answer_number_actors

question_6, question_6_number_actors = actors_with_largest_movie_gap_year(data)
print(f"The total number of actors with largest maximum gap of years is {question_6_number_actors}")
question_6
# Out:
# The total number of actors with largest maximum gap of years is 53
#                      min_year  max_year  gap
# Actors
# Abbie Cornish            2006      2016   10
# Anne Hathaway            2006      2016   10
# Audrey Tautou            2006      2016   10
# Ben Kingsley             2006      2016   10
# Ben Whishaw              2006      2016   10
# Bob Balaban              2006      2016   10
# Brad Pitt                2006      2016   10
# Bryce Dallas Howard      2006      2016   10
# Chiwetel Ejiofor         2006      2016   10
# Christian Bale           2006      2016   10
# Christopher Plummer      2006      2016   10
# Denzel Washington        2006      2016   10
# Dominic West             2006      2016   10
# Dustin Hoffman           2006      2016   10
# Edward Norton            2006      2016   10
# Ellen Burstyn            2006      2016   10
# Emily Blunt              2006      2016   10
# Eva Green                2006      2016   10
# Gerard Butler            2006      2016   10
# Hugh Jackman             2006      2016   10
# Jack Davenport           2006      2016   10
# Jennifer Aniston         2006      2016   10
# Jennifer Connelly        2006      2016   10
# Jeremy Irons             2006      2016   10
# Jessica Biel             2006      2016   10
# Johnny Depp              2006      2016   10
# Judi Dench               2006      2016   10
# Justin Theroux           2006      2016   10
# Kang-ho Song             2006      2016   10
# Kate Bosworth            2006      2016   10
# Kevin Spacey             2006      2016   10
# Kirsten Dunst            2006      2016   10
# Luke Wilson              2006      2016   10
# Marion Cotillard         2006      2016   10
# Mark Wahlberg            2006      2016   10
# Matt Damon               2006      2016   10
# Maya Rudolph             2006      2016   10
# Meryl Streep             2006      2016   10
# Michelle Monaghan        2006      2016   10
# Morgan Freeman           2006      2016   10
# Owen Wilson              2006      2016   10
# Paula Patton             2006      2016   10
# Rachel Weisz             2006      2016   10
# Russell Crowe            2006      2016   10
# Sacha Baron Cohen        2006      2016   10
# Samuel L. Jackson        2006      2016   10
# Scarlett Johansson       2006      2016   10
# Steve Carell             2006      2016   10
# Tom Cruise               2006      2016   10
# Tom Hanks                2006      2016   10
# Toni Collette            2006      2016   10
# Will Ferrell             2006      2016   10
# Will Smith               2006      2016   10

# %% [markdown]
# QUESTION 7

# %%
def find_all_actors_collaborate_with_JohnnyDepp_directly_indirectly(data):
    # Split the 'Actors' column into individual actors and explode into rows
    actors_data = data.assign(Actors=data["Actors"].str.split('|')).explode("Actors")
    
    # Create an adjacency list for collaborations (movie title -> set of actors)
    # Like "Movie 1": {"Johnny Depp", "Leonardo DiCaprio"}
    collaborations = actors_data.groupby("Title")["Actors"].apply(set).to_dict()
    
    # Using BFS to find all actors collaborating with Johnny Depp directly and indirectly
    answer = set()  # To keep track of actors we've already seen # Visited
    queue = ['Johnny Depp']  # Start the search with Johnny Depp
    
    while queue:
        current_actor = queue.pop(0)  
        if current_actor not in answer:
            answer.add(current_actor)  # Mark the actor as visited
            # Find all movies that current_actor has worked on and record the collaborated actors
            for movie_actors in collaborations.values():
                if current_actor in movie_actors:
                    queue.extend(movie_actors - answer)  # Add all unvisited co-actors to the queue
    
    # Remove Johnny Depp himself from the result
    answer.discard('Johnny Depp')
    
    return answer, len(answer)

question_7, question_7_number_collaborated_actors = find_all_actors_collaborate_with_JohnnyDepp_directly_indirectly(data)
print(f"The total number of actors that collaborate with Johnny Depp in direct and indirect ways is {question_7_number_collaborated_actors}")
question_7
# Out:
# The total number of actors that collaborate with Johnny Depp in direct and indirect ways is 1574
# {'Sonoya Mizuno',
#  'Benicio Del Toro',
#  'Helen Mirren',
#  'Jacob Tremblay',
#  'Karen Moskow',
#  'Will Dalton',
#  'Megan Fox',
#  'Tony Revolori',
#  'Matthew Morrison',
#  'Margot Robbie',
#  'Rasmus Hardiker',
#  'Shia LaBeouf',
#  'Kevin Kline',
#  'Julianna Margulies',
#  'Jason Segel',
#  'Jennifer Aniston',
#  'Thomas M. Wright',
#  'Sylvester Stallone',
#  'Brandon T. Jackson',
#  'Salim Kechiouche',
#  "Jack O'Connell",
#  'Jacki Weaver',
#  'Keri Russell',
#  'Robert Knepper',
#  'Travis Tope',
#  'Brittany Snow',
#  'Jack McBrayer',
#  'Nicolas Cage',
#  'Damaine Radcliff',
#  'Sean Faris',
#  'Ving Rhames',
#  'Michael Parks',
#  'Kevin Costner',
#  'Vincent Kartheiser',
#  'Anthony Anderson',
#  'Alec Baldwin',
#  'Sheila Kelley',
#  'Andrew Scott',
#  "Fionn O'Shea",
#  'Mel Gibson',
#  'Mateo Arias',
#  'Kelsey Grammer',
#  'Terry Crews',
#  'Michael B. Jordan',
#  'Kati Outinen',
#  'Zoe Bell',
#  'Dakota Goyo',
#  'Evan Rachel Wood',
#  'Joe Cobden',
#  'Elena Anaya',
#  'Steven Yeun',
#  'Mark Chao',
#  'Camille Cottin',
#  'Vicky Krieps',
#  'Jorma Taccone',
#  'Paul Newman',
#  'Brett Cullen',
#  'Jason Schwartzman',
#  'Zoe Kravitz',
#  'Jonah Hill',
#  'Bruno Campos',
#  'Mark Ruffalo',
#  'Mackenzie Foy',
#  'Bailey Anne Borders',
#  'Peter McRobbie',
#  'Toni Collette',
#  'Duncan Joiner',
#  'Anthony LaPaglia',
#  'Jennifer Connelly',
#  'Ronnie Gene Blevins',
#  'Analeigh Tipton',
#  'Alicia Vikander',
#  'Kang-ho Song',
#  'Anna Hutchison',
#  'Kate Upton',
#  'Abigail Breslin',
#  'Sharlto Copley',
#  'Florence Kastriner',
#  'Steve Zahn',
#  'Sebastian Stan',
#  'Ryan Guzman',
#  'David Harbour',
#  'Jim Parsons',
#  'Gabourey Sidibe',
#  'Bryan Greenberg',
#  'Robert Redford',
#  'Paul Bettany',
#  'Gerard Butler',
#  'Reese Witherspoon',
#  'Tom Cruise',
#  'Mark Wahlberg',
#  'Hugo Weaving',
#  "De'Shawn Washington",
#  'Jon Hamm',
#  'Cara Delevingne',
#  'Michelle Williams',
#  'Gerry Bednob',
#  'Aidan Gillen',
#  'Isabelle Fuhrman',
#  'Brian Marc',
#  'Tom Sizemore',
#  'Marie Gruber',
#  'Sam Riley',
#  'Woody Harrelson',
#  'Richard Gere',
#  'Morgan Freeman',
#  'Clint Dyer',
#  'Kat Dennings',
#  'Annette Bening',
#  'T.I.',
#  'Halle Berry',
#  'Jeff Kahn',
#  'Susan Sarandon',
#  'Kari Matchett',
#  'Kevin Dillon',
#  'Alan Tudyk',
#  'Brie Larson',
#  'Neil Patrick Harris',
#  'Jessica Sula',
#  "Jason O'Mara",
#  'Kerry Washington',
#  'Justin Timberlake',
#  'Brady Corbet',
#  'Natascha McElhone',
#  'George MacKay',
#  'Penelope Cruz',
#  'Judy Greer',
#  'Laurent Lucas',
#  'Michael Pitt',
#  'Benedict Wong',
#  "Auli'i Cravalho",
#  'Zachary Quinto',
#  'Linda Cardellini',
#  'Robert De Niro',
#  'Logan Paul',
#  'Anna Camp',
#  'Samantha Sloyan',
#  'Sean Bott',
#  'Jude Law',
#  'Sue Dahlman',
#  'Scott Mescudi',
#  'Keanu Reeves',
#  'Val Kilmer',
#  'Hae-il Park',
#  'Catalina Sandino Moreno',
#  'Megan Charpentier',
#  'Erin Moriarty',
#  'Alison Pill',
#  'Martin Henderson',
#  'Michael Fassbender',
#  'Max Burkholder',
#  'Michael Vartan',
#  'Sarah Gadon',
#  'Tobias Menzies',
#  'Nicole Beharie',
#  'Douglas M. Griffin',
#  'Joe Anderson',
#  'Taraji P. Henson',
#  'Lorenza Izzo',
#  'John Hurt',
#  'Nicole Parker',
#  'Tom Holland',
#  'James Frecheville',
#  'Alistair Abell',
#  'Michael Sheen',
#  'Iris Apatow',
#  'Moises Acevedo',
#  'Anton Yelchin',
#  'Jonathan Daniel Brown',
#  'Mila Kunis',
#  'Levi Miller',
#  'Stellan Skarsgard',
#  'Will Smith',
#  'Phylicia Rashad',
#  'Ansel Elgort',
#  'Frank Langella',
#  'Bella Heathcote',
#  'Derek Luke',
#  'Oprah Winfrey',
#  'Patricia Arquette',
#  'Ken Stott',
#  'Jessica Barth',
#  'Alexis Dziena',
#  'Craig Van Hook',
#  'Toby Jones',
#  'Chris Rock',
#  'Ella Rumpf',
#  'Dave Bautista',
#  'Rachel Blanchard',
#  'Lauren Holly',
#  'F. Murray Abraham',
#  'Zac Efron',
#  'Sally Phillips',
#  'Daniel Gimenez Cacho',
#  'Sean Bean',
#  'Glenn Close',
#  'Dominic West',
#  'Jim Sturgess',
#  'Jason Momoa',
#  'Adam Rodriguez',
#  'Antonia Ribero',
#  'Don Cheadle',
#  'Tyne Daly',
#  'Min-sik Choi',
#  'Jemima West',
#  'Tania Raymonde',
#  'Freddie Highmore',
#  'Sarah Dumont',
#  'Peter Stormare',
#  'Judi Dench',
#  'Stephen Merchant',
#  'Guillaume Baillargeon',
#  'Colm Feore',
#  'Michael Kenneth Williams',
#  'Fran Kranz',
#  'Arturo Castro',
#  'Allen Leech',
#  'Kevin Spacey',
#  'John Leguizamo',
#  'Maggie Grace',
#  'Angelina Jolie',
#  'Armie Hammer',
#  'Katherine Heigl',
#  'Dong-seok Ma',
#  'Matthew Fox',
#  'Eric Godon',
#  'Keira Knightley',
#  'Nathalie Baye',
#  'Theo Rossi',
#  'Laura Dern',
#  'Steele Stebbins',
#  "Beverly D'Angelo",
#  'Tammy Blanchard',
#  'Nathan Phillips',
#  'Vince Vaughn',
#  'Taika Waititi',
#  'Asa Butterfield',
#  'Josh Hutcherson',
#  'Lucy Walters',
#  'Emily Mortimer',
#  'Ana de Armas',
#  "Lupita Nyong'o",
#  'Daniel Eric Gold',
#  'Lucas Till',
#  'Ben Whishaw',
#  'Samantha Morton',
#  'Lena Endre',
#  'Emily Blunt',
#  'Kurt Russell',
#  'Kelly Macdonald',
#  'Charlotte Le Bon',
#  'Lior Ashkenazi',
#  'Tobey Maguire',
#  'Rosie Huntington-Whiteley',
#  'Anders Holm',
#  'Shailene Woodley',
#  'Melissa Leo',
#  'Julie Walters',
#  'Tom Hiddleston',
#  'Jasper Newell',
#  'Penn Badgley',
#  'Robert Sheehan',
#  'Jared Leto',
#  "Dylan O'Brien",
#  'Daisy Ridley',
#  'Oaklee Pendergast',
#  'Billy Crudup',
#  'Kirsten Dunst',
#  'Christopher Lee',
#  'Jeffrey Dean Morgan',
#  'J. Todd Smith',
#  'Nina Dobrev',
#  'Jessica Alba',
#  'Vincent Ebrahim',
#  'Rachel Korine',
#  'Tony Amendola',
#  'Tom Felton',
#  'Will Poulter',
#  'Emilie de Ravin',
#  'Rachel Wood',
#  'Tabu',
#  'Blythe Danner',
#  'Tom Wilkinson',
#  'Miles Heizer',
#  'Danny DeVito',
#  'Tim Roth',
#  'Kaitlin Olson',
#  'Temuera Morrison',
#  'Albert Finney',
#  'Mia Wasikowska',
#  'Jordan Carlos',
#  'Art Parkinson',
#  'Brendan Fraser',
#  'Paula Patton',
#  'Matthew Marsden',
#  'Richard Dreyfuss',
#  'Sarah Snook',
#  'Vera Farmiga',
#  'John Hawkes',
#  'Elizabeth Debicki',
#  'Adewale Akinnuoye-Agbaje',
#  'John Hodgman',
#  'Joseph Mawle',
#  'Harvey Keitel',
#  'Matt Lanter',
#  'Ivo Nandi',
#  'Hugh Jackman',
#  'Harry Connick Jr.',
#  'Annalise Basso',
#  'Andy Powers',
#  'Joel David Moore',
#  'Harley Quinn Smith',
#  'Matthew McConaughey',
#  'Kurt Fuller',
#  'Rihanna',
#  'Paul Dano',
#  'Ewen Leslie',
#  'Lili Taylor',
#  'Daniel Day-Lewis',
#  'Laura Linney',
#  'Alice Eve',
#  'Dax Shepard',
#  'Ashton Kutcher',
#  'Ralph Fiennes',
#  'Robbie Amell',
#  'Andrew Garfield',
#  'Justin Theroux',
#  'Hilary Swank',
#  'John Cullum',
#  'Lily Cole',
#  'Derek Jacobi',
#  'Marion Cotillard',
#  'Trenton Rogers',
#  'Edie Falco',
#  'Stephen Moyer',
#  'Billy Connolly',
#  'Milla Jovovich',
#  'Gregg Weiner',
#  'Kristen Connolly',
#  'Channing Tatum',
#  'Riley Thomas Stewart',
#  'Kristin Scott Thomas',
#  'Taissa Farmiga',
#  'Adrien Brody',
#  'Bonnie Hunt',
#  'Madeleine West',
#  'Barry Ward',
#  'Zachery Ty Bryan',
#  'Alex Pettyfer',
#  'Faith Wladyka',
#  'Olga Kurylenko',
#  'Bill Engvall',
#  'Rob Riggle',
#  'Charlie Tahan',
#  'Aldis Hodge',
#  'Ike Barinholtz',
#  'Richard Armitage',
#  'Eddie Redmayne',
#  'Dominic Cooper',
#  'Kristen Bell',
#  'Aaron Taylor-Johnson',
#  'John Gallagher Jr.',
#  'James McAvoy',
#  'Alain Moussi',
#  'Jessica Lange',
#  'Jae Head',
#  'David Lyons',
#  'Riz Ahmed',
#  'Ashlyn Sanchez',
#  'Chris Wedge',
#  'Addison Timlin',
#  'Tian Jing',
#  'Selena Gomez',
#  'Samuel L. Jackson',
#  'Duan Sanderson',
#  'Ice Cube',
#  'Dolph Lundgren',
#  'Catherine Keener',
#  'Tom Hardy',
#  'James Hamrick',
#  'Michiel Huisman',
#  'Rooney Mara',
#  'Domhnall Gleeson',
#  'Shameik Moore',
#  'Benedict Cumberbatch',
#  'Alia Shawkat',
#  'Madison Wolfe',
#  'Kate McKinnon',
#  'Alexandra Daddario',
#  'Winona Ryder',
#  'Ed Helms',
#  'Mel Raido',
#  'Jean Reno',
#  'John C. Reilly',
#  'Elijah Wood',
#  'David Denman',
#  'Joey Lauren Adams',
#  'Ellen Burstyn',
#  'Nat Wolff',
#  'Giovanni Ribisi',
#  'Salli Richardson-Whitfield',
#  'Aiden Longworth',
#  'George Clooney',
#  'Lea Seydoux',
#  'Brian Geraghty',
#  'Katee Sackhoff',
#  'Tim Allen',
#  'Austin Stowell',
#  'Rachel House',
#  'Christian Distefano',
#  'Matthew Macfadyen',
#  'Tom Hughes',
#  'Simon Pegg',
#  'Travis Fimmel',
#  'Elijah Smith',
#  'Jane Fonda',
#  'Kara Hayward',
#  'Alex R. Hibbert',
#  'Matthew Zuk',
#  'Taylor Schilling',
#  'Daniel Henshall',
#  'John Doman',
#  'Logan Marshall-Green',
#  'Judy Davis',
#  'Robert Capron',
#  'Michael Keaton',
#  'Lucy Liu',
#  'Dax Flame',
#  'Sean Bridgers',
#  'Juno Temple',
#  'Sasha Lane',
#  'Ellen Page',
#  'AJ Michalka',
#  'Yu-mi Jung',
#  'Alfre Woodard',
#  'Isabel Lucas',
#  'Daniella Kertesz',
#  'Lars Eidinger',
#  'Maddie Ziegler',
#  'Christopher Evan Welch',
#  'Thomas Mann',
#  'Astrid Berges-Frisbey',
#  'Idina Menzel',
#  'Mira Sorvino',
#  "Zac Mattoon O'Brien",
#  'Rose Byrne',
#  'Teyonah Parris',
#  'Haley Joel Osment',
#  'Gabriel Basso',
#  'Israel Broussard',
#  'Andy Lau',
#  'Katey Sagal',
#  'Mary Elizabeth Winstead',
#  'Eric Bana',
#  'Nathan Fillion',
#  'John Goodman',
#  'Cobie Smulders',
#  'Sullivan Stapleton',
#  'Ewan McGregor',
#  'Michael Constantine',
#  'Bella Thorne',
#  'Jessica Chastain',
#  'Steve Carell',
#  'Matthew Goode',
#  'Ji-min Han',
#  'Craig Ferguson',
#  'Alfie Allen',
#  'Lucy Fry',
#  'Ni Ni',
#  'Emmanuelle Chriqui',
#  'Hans Matheson',
#  'Emayatzy Corinealdi',
#  'Andie MacDowell',
#  'Natalie Portman',
#  'Ryoko Seta',
#  'Callan McAuliffe',
#  'Lainie Kazan',
#  'Naomie Harris',
#  'Devon Bostick',
#  'Kevin Nealon',
#  'Katy Barker',
#  'Rebecca Ferguson',
#  'T.J. Miller',
#  'Garrett M. Brown',
#  'Kirby Bliss Blanton',
#  'Kimberly Elise',
#  'Tommy Lee Jones',
#  'CCH Pounder',
#  'Alfred Molina',
#  'Emma Roberts',
#  'Michael Ealy',
#  'Ruby Barnhill',
#  'Jared Harris',
#  'Raghuvir Joshi',
#  'William Fichtner',
#  'Kim Cattrall',
#  'Carla Gugino',
#  'Michael Gambon',
#  'James Marsden',
#  'Linda Gegusch',
#  'Josh Peck',
#  'Anders Danielsen Lie',
#  'Patrick Dempsey',
#  'Gil Birmingham',
#  'Denzel Washington',
#  'Florence Clery',
#  'Stephen Rea',
#  'Katie Holmes',
#  'Rila Fukushima',
#  'Angelo Josue Lozano Corzo',
#  'Cillian Murphy',
#  'Rosemarie DeWitt',
#  'Arnaud Viard',
#  'Graham McTavish',
#  'Jessie Ok Gray',
#  'Stephen Dorff',
#  'Leehom Wang',
#  'Sam Shepard',
#  'Peyton List',
#  'Aaron Eckhart',
#  'Stephen Henderson',
#  'Nellie',
#  'Paddy Considine',
#  'Jaden Smith',
#  'Miyavi',
#  'Gattlin Griffith',
#  'Lewis Black',
#  'Malcolm Sinclair',
#  'Karl Urban',
#  'Saoirse Ronan',
#  'Dan Stevens',
#  'Joel Courtney',
#  'Karen Gillan',
#  'Emily Ratajkowski',
#  'John Corbett',
#  'Chris Isaak',
#  'Ruben Blades',
#  'Ruth Wilson',
#  'Valerie Mahaffey',
#  'Ben Stiller',
#  'Billy Crystal',
#  'James Ransone',
#  'Thomas Middleditch',
#  'Heath Ledger',
#  'Bryce Dallas Howard',
#  'Maggie Q',
#  'Natasha Henstridge',
#  'Mia Goth',
#  'Riley Keough',
#  'Thomas Lennon',
#  'Justin Bartha',
#  'Steven Mackintosh',
#  'Jennifer Lawrence',
#  'Garance Marillier',
#  'Martin McCann',
#  'John Travolta',
#  'Garrett Hedlund',
#  'Doona Bae',
#  'Katie Crown',
#  'Scott Speedman',
#  'Daniel Craig',
#  'Gemma Jones',
#  'Oliver Platt',
#  'Michael Rooker',
#  'Candice Bergen',
#  'Jeremy McWilliams',
#  'David Spade',
#  'Adam Pally',
#  'Haley Bennett',
#  'Joseph Gordon-Levitt',
#  'Karolina Gruszka',
#  'Julie Benz',
#  'Orlando Bloom',
#  'Kate Winslet',
#  'Brian Dennehy',
#  'Maude Apatow',
#  'Sandra Bullock',
#  'Amy Poehler',
#  'Isabella Rossellini',
#  'Taylor Kitsch',
#  'Morgan Saylor',
#  'Madina Nalwanga',
#  'Sanjeev Bhaskar',
#  'Matt Long',
#  'Mark Rylance',
#  'Barkhad Abdirahman',
#  'Amy Ryan',
#  'Michael Caine',
#  'Pierce Brosnan',
#  'Ned Beatty',
#  'Kate Beckinsale',
#  'Karin Konoval',
#  'Ryan Reynolds',
#  'Andy Serkis',
#  'Gal Gadot',
#  'Aasif Mandvi',
#  'Clifton Collins Jr.',
#  'Jason Isaacs',
#  'Michael Dickson',
#  'Karel Hermanek Jr.',
#  'Dale Dickey',
#  'Tom Mison',
#  'Bel Powley',
#  'Marisa Paredes',
#  'Jordan Nagai',
#  'Mike Vogel',
#  'Alison Sudol',
#  'Joseph Fiennes',
#  'Kagiso Kuypers',
#  'Scott Glenn',
#  'Chris Pratt',
#  'Janet McTeer',
#  'Cheryl Hines',
#  'Oona Laurence',
#  'Diego Boneta',
#  'Bree Turner',
#  'Karen Disher',
#  'Tim Blake Nelson',
#  'Eloise Mumford',
#  'Brooklyn Decker',
#  'Rupert Friend',
#  'Iain Glen',
#  'Jessica Biel',
#  'Jordi Moll?',
#  'Olivia Williams',
#  'Luke Kleintank',
#  'Christopher McDonald',
#  'Xavier Samuel',
#  'Blake Lively',
#  'Alexander Black',
#  'Annabeth Gish',
#  'Kate Bosworth',
#  'Brenton Thwaites',
#  'Olivia Munn',
#  'Gabriel Byrne',
#  'Donna Murphy',
#  'Emory Cohen',
#  'Richenda Carey',
#  'Jack Huston',
#  'Colton Haynes',
#  'Keith Carradine',
#  'Amber Tamblyn',
#  'Radha Mitchell',
#  'Tijuana Ricks',
#  'Robert Carlyle',
#  'Boyd Holbrook',
#  'Jonny Weston',
#  'John Krasinski',
#  'Aaron Burns',
#  'Laura Allen',
#  'Brooke Shields',
#  'Paul Reiser',
#  'Jay Baruchel',
#  'Alexander Skarsgard',
#  'Adrianne Palicki',
#  'Skyler Gisondo',
#  'Sylvia Hoeks',
#  'Eva Green',
#  'Terrence Howard',
#  'Arnold Schwarzenegger',
#  'Robert Patrick',
#  'Nick Frost',
#  'John Malkovich',
#  'Joe Alwyn',
#  'Kelly Adams',
#  'Benjamin Walker',
#  'Nia Vardalos',
#  'Julianne Hough',
#  'Sarah Silverman',
#  'Meryl Streep',
#  'Michael Shannon',
#  'Eva Mendes',
#  'Theo James',
#  'Charlize Theron',
#  'Jamie Chung',
#  'Charlotte Gainsbourg',
#  'Lily-Rose Depp',
#  'J.K. Simmons',
#  'America Ferrera',
#  'Sigrid Bouaziz',
#  'Brandon Routh',
#  'Dave Franco',
#  'Ian McShane',
#  'Leslie Bibb',
#  'Stacy Martin',
#  'David Oyelowo',
#  'Lou Taylor Pucci',
#  'Vanessa Hudgens',
#  'Antonio Tarver',
#  'Nicholas Galitzine',
#  'Ben Winchell',
#  'Gabriella Wilde',
#  'Miranda Cosgrove',
#  'Ty Simpkins',
#  'Timothy Spall',
#  'Juliet Rylance',
#  'Rachel Weisz',
#  'Idris Elba',
#  'Lorraine Nicholson',
#  'Dean Norris',
#  'Josh Stewart',
#  'Robin Williams',
#  'Taylor Lautner',
#  'Chloe Sevigny',
#  'Bill Nighy',
#  'Elisabeth Moss',
#  'Emilie Leclerc',
#  'Dominique McElligott',
#  'Mindy Kaling',
#  'Alexis Clagett',
#  'Joaquin Phoenix',
#  'Nick Robinson',
#  'Andrew Simpson',
#  'Peter Dinklage',
#  'Vernetta Lopez',
#  'Julian Richings',
#  'Luke Bracey',
#  'Annabelle Attanasio',
#  'Kenneth Branagh',
#  'Jamie Blackley',
#  'Jackie Chan',
#  'Nikolaj Coster-Waldau',
#  'Momo Dione',
#  'Essie Davis',
#  'Karl Glusman',
#  'Aomi Muyock',
#  'Nick Swardson',
#  'Bob Balaban',
#  'Jared Gilman',
#  'Ezra Miller',
#  'Mason Lee',
#  'Lesley Manville',
#  'Jaime Winstone',
#  'Zooey Deschanel',
#  'Juan Saavedra',
#  'Hugh Grant',
#  'Carice van Houten',
#  'Anna Kendrick',
#  'Chris Evans',
#  'Sam Neill',
#  'Margarita Levieva',
#  'Danny Glover',
#  'Lauren Graham',
#  'Dakota Blue Richards',
#  'Ang Phula Sherpa',
#  'Pablo Schreiber',
#  'Marton Csokas',
#  'Claire Danes',
#  'Jalil Lespert',
#  'Noomi Rapace',
#  'Allison Tolman',
#  '?lafur Darri ?lafsson',
#  'RJ Cyler',
#  'Liev Schreiber',
#  'Elizabeth Reaser',
#  'Sienna Miller',
#  'Emma Stone',
#  'Jason Flemyng',
#  'Toby Kebbell',
#  'Kelly Reilly',
#  'Cary-Hiroyuki Tagawa',
#  'Logan Huffman',
#  'Bill Hader',
#  'Ed Skrein',
#  'Adrian Grenier',
#  'Josh Duhamel',
#  'Michael Douglas',
#  'Nazanin Boniadi',
#  'Tao Okamoto',
#  'Freddy Rodriguez',
#  'Paul Giamatti',
#  'Mandy Gonzalez',
#  'Vin Diesel',
#  'Seth MacFarlane',
#  'Patrick Wilson',
#  'Kevin McKidd',
#  'Gary Oldman',
#  'Sarah Paulson',
#  'Alex Essoe',
#  'Victoria Justice',
#  'Edward Norton',
#  'Paula Beer',
#  'Jodie Foster',
#  'Kiersey Clemons',
#  'Kathy Bates',
#  'Ray Stevenson',
#  'Romain Duris',
#  'Gabriel Luna',
#  'Ella Anderson',
#  'Jeremy Renner',
#  'Cori Gonzalez-Macuer',
#  'Adam Driver',
#  'Noah Taylor',
#  'Adam Devine',
#  'Christoph Waltz',
#  'Jane Levy',
#  'Chris Messina',
#  'Sophie Perry',
#  'Trey Songz',
#  'Jesse Eisenberg',
#  'Shannon Woodward',
#  'Cam Gigandet',
#  'Sally Hawkins',
#  'John Cusack',
#  'Christopher Fitzgerald',
#  'Barkhad Abdi',
#  'Dominique Tipper',
#  'Woody Allen',
#  'Paul Rudd',
#  'Logan Lerman',
#  'Jake Gyllenhaal',
#  'Chadwick Boseman',
#  'James Franco',
#  'Gabriel Bateman',
#  'Andy Garcia',
#  'Robin Wright',
#  'Dane DeHaan',
#  'Damon Wayans Jr.',
#  'Britt Robertson',
#  'Cole Konis',
#  'Rima Te Wiata',
#  'Alice Englert',
#  'Kieran Culkin',
#  'Marley Shelton',
#  'Chiwetel Ejiofor',
#  'Jane Lynch',
#  'Kiefer Sutherland',
#  'Michael Cera',
#  'Kaya Scodelario',
#  'Jena Malone',
#  'Dakota Johnson',
#  'Christian Cooke',
#  'Ethan Hawke',
#  'Ray Winstone',
#  'Olivia Thirlby',
#  'Annie Rose Buckley',
#  'Rufus Sewell',
#  'Zach Galifianakis',
#  'Jennifer Morrison',
#  'Amy Adams',
#  'Zachary Gordon',
#  'Jerry Ferrara',
#  'Ed Harris',
#  'Naomi Watts',
#  'Kathryn Hahn',
#  'Queen Latifah',
#  'Ellar Coltrane',
#  'Christopher Plummer',
#  'Gabriel Chavarria',
#  'Ben Affleck',
#  'Suraj Sharma',
#  'Riccardo Scamarcio',
#  'Sienna Guillory',
#  'Tye Sheridan',
#  'Walton Goggins',
#  'Lynn Collins',
#  'Thomas Brodie-Sangster',
#  'Marlon Wayans',
#  'Lois van Wijk',
#  'Rachel McAdams',
#  'Anna Faris',
#  'Nadine Velazquez',
#  'Peter Riegert',
#  'Audrey Tautou',
#  'Tessa Thompson',
#  'Carrie-Anne Moss',
#  'Albert Brooks',
#  'Paula Prentiss',
#  'David Thewlis',
#  'Djimon Hounsou',
#  'Sophie Nelisse',
#  'Jim Broadbent',
#  'Oona Chaplin',
#  'David James',
#  'Gemma Arterton',
#  'Liam Neeson',
#  "Mo'Nique",
#  'Rose Leslie',
#  'Laurence Fishburne',
#  'Freddie Crowder',
#  'Lily James',
#  'Ralph Ineson',
#  'Jason Sudeikis',
#  'Brenda Blethyn',
#  'Cynthia Nixon',
#  'Jasmine Trinca',
#  'Tom Cullen',
#  'Pierre Niney',
#  "Vincent D'Onofrio",
#  'Billy Bob Thornton',
#  'Jennifer Koenig',
#  'Maggie Gyllenhaal',
#  'Miles Teller',
#  'Josh Brolin',
#  'Andy Samberg',
#  'Neel Sethi',
#  'Ellen DeGeneres',
#  'Don Thompson',
#  'Angela Bassett',
#  'Haley Lu Richardson',
#  'Jon Voight',
#  'Demi Moore',
#  'Elisabeth Shue',
#  'Rupert Grint',
#  'Max Minghella',
#  'Christopher Walken',
#  'Kate Hudson',
#  'Randall Park',
#  'Nicole Kidman',
#  'Geoffrey Rush',
#  'Rob Corddry',
#  'Odeya Rush',
#  'Sam Rockwell',
#  'Alan Rickman',
#  'Jim Carrey',
#  'Nick Nolte',
#  'Marcia Gay Harden',
#  'Helena Bonham Carter',
#  'Rachael Blake',
#  'Ernst Stotzner',
#  'Liv Tyler',
#  'Tony Goldwyn',
#  'Kristen Wiig',
#  'Sean Patrick Thomas',
#  'Joshua Leonard',
#  'Amanda Bynes',
#  'Elizabeth Olsen',
#  'Sarah Roemer',
#  'Jovan Adepo',
#  'Annabelle Wallis',
#  'Kyle Gallner',
#  'Tom Costello',
#  'Amanda Seyfried',
#  'Diane Lane',
#  'Jim Caviezel',
#  'Casey Affleck',
#  'Sigourney Weaver',
#  'Raffey Cassidy',
#  'Hermione Corfield',
#  'Kate Dickie',
#  'Nick Krause',
#  'Michelle Pfeiffer',
#  'Lydia Wilson',
#  'Moon Bloodgood',
#  'Keir Gilchrist',
#  'Julia Stiles',
#  'Ray Romano',
#  'Isabelle Nelisse',
#  'Jeremy Davies',
#  'Melissa Benoist',
#  'Edward Asner',
#  'Brian Caspe',
#  'Ethan Suplee',
#  'Gary Cole',
#  'Sean Penn',
#  'Rinko Kikuchi',
#  'Allison Janney',
#  'Joan Cusack',
#  'Portia Doubleday',
#  'Adil Hussain',
#  'Chris Cooper',
#  'Jennifer Saunders',
#  'Doug Jones',
#  'Andre Braugher',
#  'Isaiah Stone',
#  "Ed O'Neill",
#  'Bridgette Barrett',
#  'Henry Cavill',
#  'Wenwen Han',
#  'Charlie Day',
#  'Aurelien Recoing',
#  'Sam Trammell',
#  'Johnny Simmons',
#  'Craig Robinson',
#  'Jeff Daniels',
#  'Jeremy Irons',
#  'Paul Anderson',
#  'Harold Perrineau',
#  'Adelaide Kane',
#  'Rip Torn',
#  'Jason Barry',
#  'Joel McHale',
#  'Dianna Agron',
#  'Josh Wiggins',
#  'Logan Miller',
#  'Joel Kinnaman',
#  'January Jones',
#  'Karen Allen',
#  'Selma Blair',
#  'Carmen Ejogo',
#  'Damien Marzette',
#  'Noel Fisher',
#  'Lucas Black',
#  'Guy Pearce',
#  'John C. McGinley',
#  'Alice Braga',
#  'Colin Hanks',
#  'Moe Dunford',
#  'Oakes Fegley',
#  'Cary Joji Fukunaga',
#  ...}
